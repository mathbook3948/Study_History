# %%
import kagglehub
import shutil

# Download latest version
path = kagglehub.dataset_download("noodulz/pokemon-dataset-1000")

print("Path to dataset files:", path)

destination = "./dataset/pokemon_data"
shutil.copytree(path, destination, dirs_exist_ok=True)

# %%
import os
import shutil
import random

# Paths
base_path = destination+"/pokemon-dataset-1000"
dataset_path = os.path.join(base_path, "dataset")
train_path = os.path.join(base_path, "train")
val_path = os.path.join(base_path, "val")
test_path = os.path.join(base_path, "test")

# Create directories for train, val, and test splits
os.makedirs(train_path, exist_ok=True)
os.makedirs(val_path, exist_ok=True)
os.makedirs(test_path, exist_ok=True)

# Train-Val-Test split ratios
train_ratio = 0.8
val_ratio = 0.1
test_ratio = 0.1

# Iterate through class folders
for class_name in os.listdir(dataset_path):
    class_folder = os.path.join(dataset_path, class_name)
    if os.path.isdir(class_folder):  # Check if it's a directory
        # Get all image files in the class folder
        images = [os.path.join(class_folder, img) for img in os.listdir(class_folder) if img.endswith('.png')]

        # Shuffle images for randomness
        random.shuffle(images)

        # Calculate split sizes
        train_size = int(len(images) * train_ratio)
        val_size = int(len(images) * val_ratio)

        # Split images
        train_images = images[:train_size]
        val_images = images[train_size:train_size + val_size]
        test_images = images[train_size + val_size:]

        # Create class subfolders in train, val, and test directories
        os.makedirs(os.path.join(train_path, class_name), exist_ok=True)
        os.makedirs(os.path.join(val_path, class_name), exist_ok=True)
        os.makedirs(os.path.join(test_path, class_name), exist_ok=True)

        # Move images to respective directories
        for img in train_images:
            shutil.copy(img, os.path.join(train_path, class_name))
        for img in val_images:
            shutil.copy(img, os.path.join(val_path, class_name))
        for img in test_images:
            shutil.copy(img, os.path.join(test_path, class_name))

        print(f"Processed class: {class_name}")

print("Dataset split into train, val, and test folders.")
# Out:
# Processed class: bidoof
# Processed class: hariyama
# Processed class: sudowoodo
# Processed class: alcremie
# Processed class: diglett
# Processed class: shedinja
# Processed class: eldegoss
# Processed class: ariados
# Processed class: tyrunt
# Processed class: iron-hands
# Processed class: clawitzer
# Processed class: forretress
# Processed class: thundurus-incarnate
# Processed class: pansear
# Processed class: salandit
# Processed class: orthworm
# Processed class: lumineon
# Processed class: patrat
# Processed class: frigibax
# Processed class: rillaboom
# Processed class: watchog
# Processed class: kartana
# Processed class: sandile
# Processed class: staraptor
# Processed class: beheeyem
# Processed class: dubwool
# Processed class: bombirdier
# Processed class: magnemite
# Processed class: pidgey
# Processed class: drizzile
# Processed class: shelmet
# Processed class: golisopod
# Processed class: cosmog
# Processed class: gliscor
# Processed class: spritzee
# Processed class: drifblim
# Processed class: malamar
# Processed class: purugly
# Processed class: flamigo
# Processed class: spearow
# Processed class: braviary
# Processed class: claydol
# Processed class: tepig
# Processed class: palpitoad
# Processed class: scrafty
# Processed class: unfezant
# Processed class: klinklang
# Processed class: vibrava
# Processed class: tapu-koko
# Processed class: krabby
# Processed class: whiscash
# Processed class: gurdurr
# Processed class: nosepass
# Processed class: sinistea
# Processed class: tyrogue
# Processed class: gumshoos
# Processed class: palkia
# Processed class: basculin-red-striped
# Processed class: gigalith
# Processed class: centiskorch
# Processed class: kirlia
# Processed class: sobble
# Processed class: minccino
# Processed class: calyrex
# Processed class: snubbull
# Processed class: rowlet
# Processed class: surskit
# Processed class: flapple
# Processed class: appletun
# Processed class: sandshrew
# Processed class: karrablast
# Processed class: rufflet
# Processed class: lycanroc-midday
# Processed class: onix
# Processed class: salamence
# Processed class: cacnea
# Processed class: seismitoad
# Processed class: hoppip
# Processed class: milotic
# Processed class: golduck
# Processed class: drilbur
# Processed class: dragonair
# Processed class: haxorus
# Processed class: natu
# Processed class: spiritomb
# Processed class: manectric
# Processed class: aerodactyl
# Processed class: umbreon
# Processed class: grovyle
# Processed class: cufant
# Processed class: heracross
# Processed class: wingull
# Processed class: purrloin
# Processed class: kabutops
# Processed class: kingler
# Processed class: machop
# Processed class: vullaby
# Processed class: medicham
# Processed class: cubone
# Processed class: inkay
# Processed class: florges
# Processed class: nickit
# Processed class: kricketune
# Processed class: rayquaza
# Processed class: dhelmise
# Processed class: masquerain
# Processed class: vanillish
# Processed class: swablu
# Processed class: porygon2
# Processed class: combee
# Processed class: arctovish
# Processed class: tauros
# Processed class: dragonite
# Processed class: seaking
# Processed class: haunter
# Processed class: goodra
# Processed class: celebi
# Processed class: vileplume
# Processed class: honchkrow
# Processed class: naganadel
# Processed class: sharpedo
# Processed class: greavard
# Processed class: emolga
# Processed class: mareep
# Processed class: clamperl
# Processed class: iron-jugulis
# Processed class: simisage
# Processed class: xurkitree
# Processed class: rhydon
# Processed class: pawmot
# Processed class: eiscue-ice
# Processed class: arcanine
# Processed class: grapploct
# Processed class: flutter-mane
# Processed class: jumpluff
# Processed class: swalot
# Processed class: tyranitar
# Processed class: ferrothorn
# Processed class: xerneas
# Processed class: magneton
# Processed class: uxie
# Processed class: ditto
# Processed class: impidimp
# Processed class: tirtouga
# Processed class: totodile
# Processed class: oricorio-baile
# Processed class: pangoro
# Processed class: lucario
# Processed class: dratini
# Processed class: cradily
# Processed class: remoraid
# Processed class: loudred
# Processed class: chatot
# Processed class: eevee
# Processed class: skorupi
# Processed class: goldeen
# Processed class: lickilicky
# Processed class: ribombee
# Processed class: wugtrio
# Processed class: lombre
# Processed class: swanna
# Processed class: smoliv
# Processed class: lampent
# Processed class: barboach
# Processed class: helioptile
# Processed class: leavanny
# Processed class: carbink
# Processed class: ponyta
# Processed class: staryu
# Processed class: tarountula
# Processed class: farigiraf
# Processed class: mankey
# Processed class: cyndaquil
# Processed class: metagross
# Processed class: lillipup
# Processed class: marshadow
# Processed class: hawlucha
# Processed class: froakie
# Processed class: bayleef
# Processed class: terrakion
# Processed class: heliolisk
# Processed class: monferno
# Processed class: toedscool
# Processed class: snorunt
# Processed class: muk
# Processed class: silcoon
# Processed class: electivire
# Processed class: lokix
# Processed class: shieldon
# Processed class: scolipede
# Processed class: krookodile
# Processed class: anorith
# Processed class: tynamo
# Processed class: dartrix
# Processed class: sentret
# Processed class: pelipper
# Processed class: tropius
# Processed class: feraligatr
# Processed class: chansey
# Processed class: archen
# Processed class: maractus
# Processed class: escavalier
# Processed class: charmander
# Processed class: hypno
# Processed class: exeggutor
# Processed class: bellossom
# Processed class: mamoswine
# Processed class: slither-wing
# Processed class: quaxwell
# Processed class: doublade
# Processed class: mothim
# Processed class: morelull
# Processed class: scovillain
# Processed class: cyclizar
# Processed class: miltank
# Processed class: braixen
# Processed class: makuhita
# Processed class: clobbopus
# Processed class: shelgon
# Processed class: weavile
# Processed class: furret
# Processed class: simisear
# Processed class: rookidee
# Processed class: hatenna
# Processed class: parasect
# Processed class: sneasler
# Processed class: dragalge
# Processed class: brionne
# Processed class: piloswine
# Processed class: manaphy
# Processed class: deerling
# Processed class: palafin-zero
# Processed class: trubbish
# Processed class: krokorok
# Processed class: mr-rime
# Processed class: qwilfish
# Processed class: emboar
# Processed class: aromatisse
# Processed class: nincada
# Processed class: comfey
# Processed class: crustle
# Processed class: pawmo
# Processed class: lilligant
# Processed class: avalugg
# Processed class: machoke
# Processed class: pichu
# Processed class: morgrem
# Processed class: lotad
# Processed class: barraskewda
# Processed class: tatsugiri-curly
# Processed class: glameow
# Processed class: ceruledge
# Processed class: huntail
# Processed class: spheal
# Processed class: kingambit
# Processed class: cubchoo
# Processed class: cherubi
# Processed class: arctozolt
# Processed class: ludicolo
# Processed class: maushold-family-of-four
# Processed class: copperajah
# Processed class: sewaddle
# Processed class: mawile
# Processed class: giratina-altered
# Processed class: aegislash-shield
# Processed class: pinsir
# Processed class: nymble
# Processed class: greedent
# Processed class: rabsca
# Processed class: sylveon
# Processed class: staravia
# Processed class: floette
# Processed class: yamask
# Processed class: kilowattrel
# Processed class: blitzle
# Processed class: electrode
# Processed class: pidgeotto
# Processed class: stufful
# Processed class: lechonk
# Processed class: leafeon
# Processed class: koffing
# Processed class: aipom
# Processed class: tinkaton
# Processed class: fearow
# Processed class: lapras
# Processed class: cinccino
# Processed class: croconaw
# Processed class: boltund
# Processed class: virizion
# Processed class: ralts
# Processed class: empoleon
# Processed class: pawmi
# Processed class: rhyhorn
# Processed class: volcarona
# Processed class: bellibolt
# Processed class: beldum
# Processed class: naclstack
# Processed class: typhlosion
# Processed class: shiinotic
# Processed class: wailord
# Processed class: woobat
# Processed class: entei
# Processed class: bunnelby
# Processed class: charcadet
# Processed class: breloom
# Processed class: rotom
# Processed class: sunflora
# Processed class: pyukumuku
# Processed class: honedge
# Processed class: rampardos
# Processed class: unown
# Processed class: dewpider
# Processed class: duosion
# Processed class: glaceon
# Processed class: enamorus-incarnate
# Processed class: bellsprout
# Processed class: mantine
# Processed class: mightyena
# Processed class: houndstone
# Processed class: golem
# Processed class: feebas
# Processed class: nidorina
# Processed class: solgaleo
# Processed class: charjabug
# Processed class: swampert
# Processed class: venipede
# Processed class: vulpix
# Processed class: camerupt
# Processed class: hippopotas
# Processed class: chandelure
# Processed class: conkeldurr
# Processed class: bouffalant
# Processed class: eternatus
# Processed class: roggenrola
# Processed class: marill
# Processed class: volbeat
# Processed class: kangaskhan
# Processed class: clefairy
# Processed class: hydreigon
# Processed class: basculegion-male
# Processed class: ledian
# Processed class: skrelp
# Processed class: roserade
# Processed class: regidrago
# Processed class: pancham
# Processed class: zangoose
# Processed class: foongus
# Processed class: volcanion
# Processed class: azelf
# Processed class: toxicroak
# Processed class: riolu
# Processed class: larvitar
# Processed class: quilladin
# Processed class: keldeo-ordinary
# Processed class: doduo
# Processed class: vanillite
# Processed class: steenee
# Processed class: deoxys-normal
# Processed class: sandslash
# Processed class: snover
# Processed class: eelektrik
# Processed class: cofagrigus
# Processed class: numel
# Processed class: cetitan
# Processed class: yamper
# Processed class: cacturne
# Processed class: houndoom
# Processed class: decidueye
# Processed class: carracosta
# Processed class: ledyba
# Processed class: chinchou
# Processed class: quagsire
# Processed class: toxapex
# Processed class: pyroar
# Processed class: dunsparce
# Processed class: kleavor
# Processed class: kabuto
# Processed class: herdier
# Processed class: porygon
# Processed class: gligar
# Processed class: teddiursa
# Processed class: poochyena
# Processed class: stoutland
# Processed class: paras
# Processed class: gyarados
# Processed class: vikavolt
# Processed class: finneon
# Processed class: abomasnow
# Processed class: musharna
# Processed class: silvally
# Processed class: sawk
# Processed class: trapinch
# Processed class: primarina
# Processed class: larvesta
# Processed class: slakoth
# Processed class: guzzlord
# Processed class: chespin
# Processed class: spinda
# Processed class: hitmontop
# Processed class: orbeetle
# Processed class: cursola
# Processed class: ampharos
# Processed class: blaziken
# Processed class: mesprit
# Processed class: scream-tail
# Processed class: budew
# Processed class: hitmonlee
# Processed class: gastly
# Processed class: rolycoly
# Processed class: overqwil
# Processed class: tsareena
# Processed class: cinderace
# Processed class: oddish
# Processed class: shiftry
# Processed class: zweilous
# Processed class: relicanth
# Processed class: silicobra
# Processed class: sableye
# Processed class: minior-red-meteor
# Processed class: growlithe
# Processed class: smoochum
# Processed class: wishiwashi-solo
# Processed class: dreepy
# Processed class: gothitelle
# Processed class: wailmer
# Processed class: litten
# Processed class: palossand
# Processed class: blissey
# Processed class: dialga
# Processed class: lileep
# Processed class: quaxly
# Processed class: cosmoem
# Processed class: pikachu
# Processed class: tapu-bulu
# Processed class: noctowl
# Processed class: toxtricity-amped
# Processed class: linoone
# Processed class: zoroark
# Processed class: butterfree
# Processed class: dondozo
# Processed class: alakazam
# Processed class: graveler
# Processed class: cleffa
# Processed class: suicune
# Processed class: xatu
# Processed class: pumpkaboo-average
# Processed class: cutiefly
# Processed class: meganium
# Processed class: lopunny
# Processed class: shroomish
# Processed class: dottler
# Processed class: gourgeist-average
# Processed class: slowking
# Processed class: minun
# Processed class: cottonee
# Processed class: corvisquire
# Processed class: shellos
# Processed class: abra
# Processed class: pachirisu
# Processed class: stunfisk
# Processed class: spinarak
# Processed class: mandibuzz
# Processed class: skarmory
# Processed class: sandy-shocks
# Processed class: luxray
# Processed class: espeon
# Processed class: shinx
# Processed class: vespiquen
# Processed class: meloetta-aria
# Processed class: zapdos
# Processed class: gossifleur
# Processed class: gothorita
# Processed class: petilil
# Processed class: slugma
# Processed class: solosis
# Processed class: milcery
# Processed class: victreebel
# Processed class: wooper
# Processed class: poipole
# Processed class: joltik
# Processed class: thwackey
# Processed class: octillery
# Processed class: elekid
# Processed class: aurorus
# Processed class: crawdaunt
# Processed class: jirachi
# Processed class: grimmsnarl
# Processed class: farfetchd
# Processed class: starmie
# Processed class: blipbug
# Processed class: torkoal
# Processed class: machamp
# Processed class: kyurem
# Processed class: luvdisc
# Processed class: sigilyph
# Processed class: kommo-o
# Processed class: cramorant
# Processed class: trumbeak
# Processed class: dolliv
# Processed class: spectrier
# Processed class: chingling
# Processed class: grumpig
# Processed class: sceptile
# Processed class: buneary
# Processed class: beautifly
# Processed class: sunkern
# Processed class: timburr
# Processed class: cascoon
# Processed class: flabebe
# Processed class: shuppet
# Processed class: morpeko-full-belly
# Processed class: flaaffy
# Processed class: skiploom
# Processed class: axew
# Processed class: banette
# Processed class: jigglypuff
# Processed class: darkrai
# Processed class: baxcalibur
# Processed class: iron-treads
# Processed class: zamazenta
# Processed class: deino
# Processed class: regigigas
# Processed class: togetic
# Processed class: bagon
# Processed class: donphan
# Processed class: bisharp
# Processed class: chewtle
# Processed class: pikipek
# Processed class: coalossal
# Processed class: mimikyu-disguised
# Processed class: reshiram
# Processed class: grimer
# Processed class: phanpy
# Processed class: magmortar
# Processed class: espurr
# Processed class: flittle
# Processed class: varoom
# Processed class: shroodle
# Processed class: meowscarada
# Processed class: tinkatink
# Processed class: slowpoke
# Processed class: wobbuffet
# Processed class: corviknight
# Processed class: tapu-fini
# Processed class: araquanid
# Processed class: servine
# Processed class: buzzwole
# Processed class: darmanitan-standard
# Processed class: vigoroth
# Processed class: wormadam-plant
# Processed class: golett
# Processed class: gulpin
# Processed class: regice
# Processed class: simipour
# Processed class: exploud
# Processed class: galvantula
# Processed class: phantump
# Processed class: corphish
# Processed class: tinkatuff
# Processed class: weezing
# Processed class: armarouge
# Processed class: skeledirge
# Processed class: drakloak
# Processed class: gallade
# Processed class: type-null
# Processed class: garbodor
# Processed class: celesteela
# Processed class: nidoran-m
# Processed class: poliwag
# Processed class: mr-mime
# Processed class: clauncher
# Processed class: iron-bundle
# Processed class: delphox
# Processed class: togedemaru
# Processed class: tentacruel
# Processed class: frosmoth
# Processed class: polteageist
# Processed class: charizard
# Processed class: dusknoir
# Processed class: solrock
# Processed class: frogadier
# Processed class: hakamo-o
# Processed class: ivysaur
# Processed class: dusclops
# Processed class: accelgor
# Processed class: zarude
# Processed class: carvanha
# Processed class: thievul
# Processed class: omanyte
# Processed class: glimmet
# Processed class: sealeo
# Processed class: seel
# Processed class: tapu-lele
# Processed class: cloyster
# Processed class: garchomp
# Processed class: azumarill
# Processed class: heatran
# Processed class: raticate
# Processed class: golbat
# Processed class: registeel
# Processed class: snivy
# Processed class: luxio
# Processed class: furfrou
# Processed class: gardevoir
# Processed class: zigzagoon
# Processed class: mewtwo
# Processed class: obstagoon
# Processed class: taillow
# Processed class: vivillon
# Processed class: turtwig
# Processed class: articuno
# Processed class: starly
# Processed class: dragapult
# Processed class: pineco
# Processed class: pawniard
# Processed class: wigglytuff
# Processed class: kricketot
# Processed class: archeops
# Processed class: revavroom
# Processed class: iron-moth
# Processed class: gible
# Processed class: exeggcute
# Processed class: vanilluxe
# Processed class: capsakid
# Processed class: bramblin
# Processed class: scraggy
# Processed class: serperior
# Processed class: groudon
# Processed class: drampa
# Processed class: nihilego
# Processed class: pheromosa
# Processed class: spewpa
# Processed class: eelektross
# Processed class: iron-thorns
# Processed class: lunatone
# Processed class: bulbasaur
# Processed class: chimecho
# Processed class: necrozma
# Processed class: alomomola
# Processed class: ducklett
# Processed class: swirlix
# Processed class: diggersby
# Processed class: pincurchin
# Processed class: electabuzz
# Processed class: marshtomp
# Processed class: tentacool
# Processed class: klang
# Processed class: pupitar
# Processed class: zorua
# Processed class: marowak
# Processed class: mudkip
# Processed class: spoink
# Processed class: cranidos
# Processed class: hoopa
# Processed class: swoobat
# Processed class: landorus-incarnate
# Processed class: dracozolt
# Processed class: hatterene
# Processed class: drapion
# Processed class: skwovet
# Processed class: tangrowth
# Processed class: oshawott
# Processed class: hattrem
# Processed class: piplup
# Processed class: passimian
# Processed class: torracat
# Processed class: psyduck
# Processed class: smeargle
# Processed class: shuckle
# Processed class: quaquaval
# Processed class: bronzong
# Processed class: veluza
# Processed class: gengar
# Processed class: delcatty
# Processed class: blacephalon
# Processed class: melmetal
# Processed class: armaldo
# Processed class: crobat
# Processed class: wooloo
# Processed class: swinub
# Processed class: garganacl
# Processed class: victini
# Processed class: yungoos
# Processed class: kakuna
# Processed class: bergmite
# Processed class: arbok
# Processed class: bastiodon
# Processed class: skiddo
# Processed class: magby
# Processed class: roselia
# Processed class: drowzee
# Processed class: persian
# Processed class: prinplup
# Processed class: dedenne
# Processed class: jolteon
# Processed class: beartic
# Processed class: mareanie
# Processed class: duskull
# Processed class: crocalor
# Processed class: dewgong
# Processed class: quilava
# Processed class: bronzor
# Processed class: mime-jr
# Processed class: girafarig
# Processed class: pignite
# Processed class: yanmega
# Processed class: genesect
# Processed class: bruxish
# Processed class: lunala
# Processed class: meltan
# Processed class: duraludon
# Processed class: scorbunny
# Processed class: finizen
# Processed class: gothita
# Processed class: fomantis
# Processed class: nuzleaf
# Processed class: regieleki
# Processed class: wynaut
# Processed class: excadrill
# Processed class: liepard
# Processed class: tadbulb
# Processed class: electrike
# Processed class: venonat
# Processed class: wyrdeer
# Processed class: espathra
# Processed class: phione
# Processed class: arctibax
# Processed class: altaria
# Processed class: mismagius
# Processed class: trevenant
# Processed class: mudbray
# Processed class: magcargo
# Processed class: magmar
# Processed class: geodude
# Processed class: ninetales
# Processed class: ursaring
# Processed class: spidops
# Processed class: stonjourner
# Processed class: snorlax
# Processed class: tympole
# Processed class: reuniclus
# Processed class: magearna
# Processed class: shellder
# Processed class: squirtle
# Processed class: sprigatito
# Processed class: venusaur
# Processed class: gholdengo
# Processed class: amaura
# Processed class: nidoqueen
# Processed class: latios
# Processed class: lickitung
# Processed class: sawsbuck
# Processed class: clodsire
# Processed class: raichu
# Processed class: togekiss
# Processed class: dustox
# Processed class: illumise
# Processed class: hippowdon
# Processed class: sandygast
# Processed class: granbull
# Processed class: tyrantrum
# Processed class: falinks
# Processed class: dodrio
# Processed class: slaking
# Processed class: zubat
# Processed class: arceus
# Processed class: toucannon
# Processed class: beedrill
# Processed class: zacian
# Processed class: gogoat
# Processed class: nidoking
# Processed class: aron
# Processed class: slurpuff
# Processed class: torterra
# Processed class: noibat
# Processed class: ursaluna
# Processed class: combusken
# Processed class: meowstic-male
# Processed class: caterpie
# Processed class: regirock
# Processed class: gabite
# Processed class: weedle
# Processed class: porygon-z
# Processed class: samurott
# Processed class: brambleghast
# Processed class: incineroar
# Processed class: yveltal
# Processed class: perrserker
# Processed class: lanturn
# Processed class: turtonator
# Processed class: pansage
# Processed class: inteleon
# Processed class: scyther
# Processed class: venomoth
# Processed class: hoothoot
# Processed class: binacle
# Processed class: durant
# Processed class: zebstrika
# Processed class: ferroseed
# Processed class: stunky
# Processed class: seadra
# Processed class: litwick
# Processed class: raikou
# Processed class: floragato
# Processed class: fletchling
# Processed class: gastrodon
# Processed class: greninja
# Processed class: nacli
# Processed class: shaymin-land
# Processed class: bewear
# Processed class: darumaka
# Processed class: mew
# Processed class: arrokuda
# Processed class: gloom
# Processed class: toxel
# Processed class: sneasel
# Processed class: primeape
# Processed class: rattata
# Processed class: delibird
# Processed class: annihilape
# Processed class: jangmo-o
# Processed class: sandaconda
# Processed class: stakataka
# Processed class: moltres
# Processed class: swadloon
# Processed class: mabosstiff
# Processed class: poliwhirl
# Processed class: grookey
# Processed class: great-tusk
# Processed class: vaporeon
# Processed class: chesnaught
# Processed class: stantler
# Processed class: crabominable
# Processed class: dewott
# Processed class: treecko
# Processed class: probopass
# Processed class: dudunsparce-two-segment
# Processed class: carkol
# Processed class: jynx
# Processed class: murkrow
# Processed class: ambipom
# Processed class: charmeleon
# Processed class: panpour
# Processed class: drednaw
# Processed class: yanma
# Processed class: kubfu
# Processed class: oinkologne-male
# Processed class: cresselia
# Processed class: kingdra
# Processed class: talonflame
# Processed class: flareon
# Processed class: glimmora
# Processed class: lugia
# Processed class: cryogonal
# Processed class: jellicent
# Processed class: popplio
# Processed class: grotle
# Processed class: pidgeot
# Processed class: cherrim
# Processed class: runerigus
# Processed class: glastrier
# Processed class: mienfoo
# Processed class: wimpod
# Processed class: magnezone
# Processed class: zekrom
# Processed class: raboot
# Processed class: lurantis
# Processed class: clefable
# Processed class: tornadus-incarnate
# Processed class: komala
# Processed class: carnivine
# Processed class: sirfetchd
# Processed class: floatzel
# Processed class: lairon
# Processed class: rockruff
# Processed class: aggron
# Processed class: swellow
# Processed class: fennekin
# Processed class: boldore
# Processed class: azurill
# Processed class: steelix
# Processed class: munchlax
# Processed class: walrein
# Processed class: ho-oh
# Processed class: voltorb
# Processed class: infernape
# Processed class: tandemaus
# Processed class: chimchar
# Processed class: squawkabilly-green-plumage
# Processed class: plusle
# Processed class: cetoddle
# Processed class: sizzlipede
# Processed class: dachsbun
# Processed class: misdreavus
# Processed class: poliwrath
# Processed class: zygarde-50
# Processed class: fuecoco
# Processed class: noivern
# Processed class: whirlipede
# Processed class: mantyke
# Processed class: nidoran-f
# Processed class: wiglett
# Processed class: bounsweet
# Processed class: rellor
# Processed class: oranguru
# Processed class: wartortle
# Processed class: tranquill
# Processed class: fidough
# Processed class: nidorino
# Processed class: castform
# Processed class: horsea
# Processed class: dugtrio
# Processed class: weepinbell
# Processed class: rapidash
# Processed class: togepi
# Processed class: druddigon
# Processed class: ninjask
# Processed class: throh
# Processed class: bibarel
# Processed class: gimmighoul
# Processed class: barbaracle
# Processed class: absol
# Processed class: fraxure
# Processed class: slowbro
# Processed class: salazzle
# Processed class: seedot
# Processed class: drifloon
# Processed class: cobalion
# Processed class: golurk
# Processed class: scizor
# Processed class: scatterbug
# Processed class: brute-bonnet
# Processed class: happiny
# Processed class: hitmonchan
# Processed class: torchic
# Processed class: elgyem
# Processed class: klefki
# Processed class: grubbin
# Processed class: indeedee-male
# Processed class: croagunk
# Processed class: dracovish
# Processed class: bonsly
# Processed class: audino
# Processed class: houndour
# Processed class: glalie
# Processed class: crabrawler
# Processed class: litleo
# Processed class: whismur
# Processed class: meditite
# Processed class: arboliva
# Processed class: fletchinder
# Processed class: tangela
# Processed class: omastar
# Processed class: baltoy
# Processed class: burmy
# Processed class: toedscruel
# Processed class: applin
# Processed class: mienshao
# Processed class: skuntank
# Processed class: mudsdale
# Processed class: zeraora
# Processed class: froslass
# Processed class: amoonguss
# Processed class: igglybuff
# Processed class: magikarp
# Processed class: skitty
# Processed class: kadabra
# Processed class: urshifu-single-strike
# Processed class: dwebble
# Processed class: klink
# Processed class: munna
# Processed class: kecleon
# Processed class: ekans
# Processed class: whimsicott
# Processed class: goomy
# Processed class: diancie
# Processed class: latias
# Processed class: metapod
# Processed class: kyogre
# Processed class: meowth
# Processed class: snom
# Processed class: corsola
# Processed class: maschiff
# Processed class: heatmor
# Processed class: rhyperior
# Processed class: metang
# Processed class: buizel
# Processed class: blastoise
# Processed class: grafaiai
# Processed class: chikorita
# Processed class: wattrel
# Processed class: pidove
# Processed class: wurmple
# Processed class: klawf
# Processed class: sliggoo
# Processed class: seviper
# Processed class: frillish
# Processed class: politoed
# Processed class: flygon
# Processed class: gorebyss
# Dataset split into train, val, and test folders.

# %%
import tensorflow as tf

# %%
train = tf.keras.preprocessing.image_dataset_from_directory(
    directory="./dataset/pokemon_data/pokemon-dataset-1000/train",
    image_size = (224, 224),
    batch_size = 32,
    shuffle = True
)
val = tf.keras.preprocessing.image_dataset_from_directory(
    directory="./dataset/pokemon_data/pokemon-dataset-1000/val",
    image_size = (224, 224),
    batch_size = 32,
    shuffle = True
)
# Out:
# Found 26288 files belonging to 1000 classes.
# Found 6469 files belonging to 1000 classes.

# %%
train = train.map(lambda x, y: (x/255.0, tf.one_hot(y, len(train.class_names))))
val = val.map(lambda x, y: (x/255.0, tf.one_hot(y, len(val.class_names))))

# %%
input = tf.keras.Input(shape=(224, 224, 3))

conv1 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu')(input)
norm1 = tf.keras.layers.BatchNormalization()(conv1)
pool1 = tf.keras.layers.MaxPooling2D((2, 2))(norm1)
conv2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu')(pool1)
norm2 = tf.keras.layers.BatchNormalization()(conv2)

flatten = tf.keras.layers.Flatten()(norm2)
dense1 = tf.keras.layers.Dense(128, activation='relu')(flatten)
output = tf.keras.layers.Dense(1000, activation='softmax')(dense1)

model = tf.keras.Model(input, output)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 222, 222, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 109, 109, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 109, 109, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 380192)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │      48,664,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1000)                │         129,000 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 48,804,104 (186.17 MB)
#  Trainable params: 48,803,976 (186.17 MB)
#  Non-trainable params: 128 (512.00 B)

# %%
initial_learning_rate = 0.0001
decay_steps = 1000
decay_rate = 0.9

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=decay_steps,
    decay_rate=decay_rate,
    staircase=True)

optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
history = model.fit(
    train,
    validation_data=val,
    epochs=5,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/5
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 63s 68ms/step - accuracy: 0.0239 - loss: 7.0488 - val_accuracy: 0.2402 - val_loss: 4.5537
# Epoch 2/5
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 45s 54ms/step - accuracy: 0.3141 - loss: 4.0536 - val_accuracy: 0.7446 - val_loss: 1.2636
# Epoch 3/5
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 81s 54ms/step - accuracy: 0.7660 - loss: 1.1824 - val_accuracy: 0.9510 - val_loss: 0.2654
# Epoch 4/5
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 85s 57ms/step - accuracy: 0.9409 - loss: 0.2856 - val_accuracy: 0.9864 - val_loss: 0.0848
# Epoch 5/5
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 79s 54ms/step - accuracy: 0.9837 - loss: 0.0752 - val_accuracy: 0.9940 - val_loss: 0.0437

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plot settings
plt.figure(figsize=(12, 8))

# Plot training & validation accuracy values
plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'], 'o-', label='Training accuracy')
plt.plot(history.history['val_accuracy'], 'o-', label='Validation accuracy')
plt.title('Model accuracy', pad=20)
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'], 'o-', label='Training loss')
plt.plot(history.history['val_loss'], 'o-', label='Validation loss')
plt.title('Model loss', pad=20)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
model.save("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test = tf.keras.preprocessing.image_dataset_from_directory(
    directory="./dataset/pokemon_data/pokemon-dataset-1000/test",
    image_size = (224, 224),
    batch_size = 32,
    shuffle = True
)
# Out:
# Found 8464 files belonging to 1000 classes.

# %%
# 먼저 class_names 저장
class_names = test.class_names

# 데이터 전처리
test = test.map(lambda x, y: (x/255.0, tf.one_hot(y, len(test.class_names))))

# 예측
for images, labels in test.take(1):
    predictions = model.predict(images)

    # 처음 10개 이미지에 대한 예측 결과 출력
    for i in range(min(10, len(predictions))):
        predicted_class = class_names[np.argmax(predictions[i])]
        true_class = class_names[np.argmax(labels[i])]
        confidence = np.max(predictions[i])

        print(f"이미지 {i+1}:")
        print(f"  예측: {predicted_class}")
        print(f"  실제: {true_class}")
        print(f"  신뢰도: {confidence:.2%}")
        print()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 이미지 1:
#   예측: finneon
#   실제: finneon
#   신뢰도: 99.94%
#
# 이미지 2:
#   예측: vibrava
#   실제: vibrava
#   신뢰도: 97.77%
#
# 이미지 3:
#   예측: tornadus-incarnate
#   실제: tornadus-incarnate
#   신뢰도: 99.88%
#
# 이미지 4:
#   예측: comfey
#   실제: comfey
#   신뢰도: 99.45%
#
# 이미지 5:
#   예측: chikorita
#   실제: chikorita
#   신뢰도: 99.99%
#
# 이미지 6:
#   예측: sealeo
#   실제: sealeo
#   신뢰도: 99.99%
#
# 이미지 7:
#   예측: maschiff
#   실제: maschiff
#   신뢰도: 99.89%
#
# 이미지 8:
#   예측: wooper
#   실제: wooper
#   신뢰도: 100.00%
#
# 이미지 9:
#   예측: slugma
#   실제: slugma
#   신뢰도: 98.71%
#
# 이미지 10:
#   예측: haunter
#   실제: haunter
#   신뢰도: 99.99%
